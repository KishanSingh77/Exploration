# %%
from __future__ import print_function
import collections
import os
import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import Dense, Activation, Embedding, Flatten, Dropout, TimeDistributed, Reshape, Lambda
from keras.layers import LSTM
from keras.optimizers import RMSprop, Adam, SGD
from keras import backend as K
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
import numpy as np
import argparse
import pdb

# %%
data_path = "./inputs"
file_name = "shakespeare.txt"

# %%
def read_words(filename):
    with tf.gfile.GFile(filename, "r") as f:
        return f.read().decode("utf-8").replace("\n", "<eos>").split()
    
def build_vocab(filename):
    data = read_words(filename)
    counter = collections.Counter(data)
    count_pairs = sorted(counter.items(), key = lambda x : (-x[1], x[0]))
    words, _ = zip(*count_pairs)
    word_to_id = dict(zip(words, range(len(words))))
    return word_to_id

def file_to_word_ids(filename, word_to_id):
    data = read_words(filename)
    return [word_to_id[x] for x in data if x in word_to_id]

def load_data():
    train_path = os.path.join(data_path, file_name)
    valid_path = os.path.join(data_path, file_name)
    test_path = os.path.join(data_path, file_name)

    # build the complete vocabulary, then convert text data to list of integers
    word_to_id = build_vocab(train_path)
    train_data = file_to_word_ids(train_path, word_to_id)
    valid_data = file_to_word_ids(valid_path, word_to_id)
    test_data = file_to_word_ids(test_path, word_to_id)
    vocabulary = len(word_to_id)
    reversed_dictionary = dict(zip(word_to_id.values(), word_to_id.keys()))
    print(train_data[:5])
    print(word_to_id)
    print(vocabulary)
    print(" ".join([reversed_dictionary[x] for x in train_data[:10]]))
    return train_data, valid_data, test_data, vocabulary, reversed_dictionary

train_data, valid_data, test_data, vocabulary, reversed_dictionary = load_data()
# Out:
# [1432, 1574, 210, 1, 118]
# {u'fawn': 3428, u'tongue!<eos>JOAN': 6237, u'Mortimer': 1739, u'foul': 1033, u'four': 1034, u'PUCELLE<eos>Why,': 1815, u'hanging': 3840, u'hand:<eos>A': 3829, u'men<eos>That': 4598, u'towns': 337, u'marching': 679, u"blood,<eos>I'll": 2437, u'town.<eos>Now': 6267, u"rich-jewel'd": 5472, u'rear<eos>Than': 5343, u'lord': 129, u'opportunity<eos>As': 4872, u"Dauphin!'": 1535, u'c<eos><eos>TALBOT<eos>He': 2562, u'severity.<eos>COUNTESS<eos>OF': 5624, u'slothful': 5758, u'rashly': 5318, u'fight:<eos>If': 3471, u'wood:': 6678, u'Minotaurs': 1738, u'disturb': 981, u"cropp'd": 2882, u'wooden': 1396, u'magnifiest': 4466, u'Tomyris': 1962, u'feet,<eos>And': 3443, u'sorceress,<eos>Hath': 5805, u'shows': 5673, u'glassy': 3712, u'testify<eos>She': 6099, u'her,': 307, u'her!': 3943, u'railing': 5308, u'second': 5585, u'be;<eos>My': 2343, u'valiant': 191, u"pitch'd,<eos>To": 5054, u'up?<eos>If': 6389, u'relieving': 5387, u'nature,': 4725, u'thunder': 6201, u'fingers': 3484, u'France;<eos>Behold': 1609, u'lowliness': 4446, u'asleep:<eos>Now': 2251, u'conjure': 2768, u'queen:<eos>For': 5290, u'funeral:<eos>And': 3658, u'it?<eos>TALBOT<eos>Thy': 4170, u'honour.<eos>YORK<eos>O': 4021, u'me.<eos>REIGNIER<eos>Suffolk,': 4546, u'here': 80, u'herd': 3950, u'WINCHESTER<eos>As': 2006, u'excursion<eos><eos>TALBOT<eos>France,': 3334, u'smock;<eos>Else': 5768, u'substance': 533, u'pieces,': 5046, u'homicide;<eos>He': 4017, u'golden': 651, u'whoso': 6599, u'divide': 3139, u'contumelious': 2805, u'place;<eos>Blue': 5071, u'brought': 366, u'Boy<eos>Master-Gunner': 1487, u'stern': 741, u'away.<eos>JOHN': 2291, u'effect?<eos>After': 3237, u'reverenced': 1241, u'music': 4691, u'therefore': 172, u'strike': 531, u'until': 1353, u"confederates.<eos>BEDFORD<eos>'Tis": 2757, u'Talbot,<eos>Who': 1941, u'holy': 237, u'sent?<eos>LUCY<eos>Submission,': 5607, u'hurt': 4059, u'sea.<eos>Exeunt': 5583, u'hurl': 4056, u'himself?<eos>Adorn': 4006, u'hold': 310, u'myself<eos>Will': 4703, u'Attendants<eos><eos>An': 1465, u'again.<eos>TALBOT<eos>If': 2119, u'ourself,<eos>To': 4891, u'arms;<eos>All': 2232, u'artillery': 2243, u'there<eos>More': 6155, u'breath,<eos>That': 2520, u'want': 542, u'John?<eos>Triumphant': 1701, u'York:<eos>Darest': 2053, u'LA': 38, u'travel': 6290, u'night.<eos>RICHARD<eos>PLANTAGENET<eos>Good': 4752, u"o'ermatch'd": 4800, u'how': 88, u'hot': 1090, u'youth,': 1409, u'destruction:<eos>To': 3056, u'forth.<eos>But': 3603, u'redeem<eos>And': 5364, u'A': 792, u'beauty': 597, u'wrong': 344, u'alarum<eos><eos>Hark,': 2147, u'WINCHESTER<eos>Charles,': 2008, u'scourge': 725, u'first-begotten': 3489, u'scoffs': 5570, u'Rouen.<eos>BASTARD': 1866, u'Another': 1457, u'keeps': 1107, u'wine': 6627, u'shipping;': 5656, u'Sentinels<eos>Sergeant<eos>Sirs,': 1887, u'hell.<eos>REIGNIER<eos>If': 3929, u'throats.<eos>Bedford,': 6196, u'cause,<eos>Moved': 2609, u'wrought': 1403, u'Circe': 1520, u'you:<eos>Pucelle': 6758, u'ashamed<eos>With': 2245, u'fit': 1021, u'striking': 5961, u'rescued': 715, u'nobles': 1170, u'known:<eos>Late': 4257, u"over-veil'd": 4915, u'rage,<eos>To-morrow': 5305, u'welcome.': 6573, u'grievous': 3784, u'enrich': 3287, u'death.<eos>KING': 2973, u'execution!<eos>WARWICK<eos>And': 3339, u'enow:<eos>Place': 3284, u'burial': 918, u'over-daring': 4910, u"bearing-cloth<eos>I'll": 2353, u'message': 1154, u'prevail,<eos>Or': 5176, u'keys': 4197, u'England;<eos>And': 1553, u'tongue,<eos>Else': 6238, u'ALENCON,': 161, u'assured': 2259, u'keys<eos><eos>COUNTESS<eos>OF': 4198, u'prince.<eos>SOMERSET<eos>And': 5197, u'crowned': 961, u'knit': 4249, u'heart.<eos>BISHOP<eos>OF': 3897, u'chair.<eos>But,': 2624, u"mad-brain'd": 4457, u'thereto;<eos>And': 6158, u'speedy': 738, u'dwarf!<eos>It': 3206, u'legate:': 4312, u"warn'd.<eos>SOMERSET<eos>Ah,": 6513, u"gather'd": 3676, u'wast': 1371, u'wash': 6531, u'instruct': 1101, u'clamorous': 2677, u'Waterford': 2029, u'me!': 4538, u'Exeunt': 559, u'service': 1261, u'marry,': 1145, u'gather:<eos>But': 3677, u'legs': 4314, u's ...
# 6775
# <eos>The First part of King Henry the Sixth<eos>Shakespeare homepage |

# %%
class KerasBatchGenerator(object):
    def __init__(self, data, num_steps, batch_size, vocabulary, skip_step = 5):
        self.data = data
        self.num_steps = num_steps
        self.batch_size = batch_size
        self.vocabulary = vocabulary
        self.current_idx = 0
        self.skip_step = skip_step
        
    def generate(self):
        x = np.zeros((self.batch_size, self.num_steps))
        y = np.zeros((self.batch_size, self.num_steps, self.vocabulary))
        while True:
            for i in range(self.batch_size):
                if self.current_idx + self.num_steps >= len(self.data):
                    self.current_idx = 0
                x[i, :] = self.data[self.current_idx:self.current_idx + self.num_steps]
                temp_y = self.data[self.current_idx + 1 : self.current_idx + self.num_steps + 1]
                y[i, :, :] = to_categorical(temp_y, num_classes = self.vocabulary)
                self.current_idx += self.skip_step
                
        yield x, y

# %%
num_steps = 30
batch_size = 20
train_data_generator = KerasBatchGenerator(train_data, num_steps, batch_size, vocabulary, skip_step = num_steps)
valid_data_generator = KerasBatchGenerator(valid_data, num_steps, batch_size, vocabulary,
                                           skip_step=num_steps)

for x, y in train_data_generator.generate():
    print(x, y)

# %%
hidden_size = 500
use_dropout = True
model = Sequential()
model.add(Embedding(vocabulary, hidden_size, input_length = num_steps))
model.add(LSTM(hidden_size, return_sequences = True))
model.add(LSTM(hidden_size, return_sequences = True))
if use_dropout:
    model.add(Dropout(0.5))
model.add(TimeDistributed(Dense(vocabulary)))
model.add(Activation("softmax"))


optimizer = Adam()
model.compile(loss = "categorical_crossentropy", optimizer = "adam", metrics=['categorical_accuracy'])


print(model.summary())
# Out:
# 6775
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 30, 500)           3387500
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 500)           2002000
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 30, 500)           2002000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 500)           0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 30, 6775)          3394275
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 6775)          0
# =================================================================
# Total params: 10,785,775
# Trainable params: 10,785,775
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
checkpointer = ModelCheckpoint(filepath=data_path + '/model-{epoch:02d}.hdf5', verbose=1)
num_epochs = 50

model.fit_generator(train_data_generator.generate(), len(train_data)//(batch_size*num_steps), num_epochs,
                        validation_data=valid_data_generator.generate(),
                        validation_steps=len(valid_data)//(batch_size*num_steps), callbacks=[checkpointer])
    # model.fit_generator(train_data_generator.generate(), 2000, num_epochs,
    #                     validation_data=valid_data_generator.generate(),
    #                     validation_steps=10)
    model.save(data_path + "final_model.hdf5")
